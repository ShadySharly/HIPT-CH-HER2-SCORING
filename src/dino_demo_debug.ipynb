# %%
from dataset import DinoDataset

# %%
dataset_debug = DinoDataset(
    **{
        "partitions_src": "/home/bgamboa/side_projects/HIPT-CH-HER2-SCORING/src/data/partitions_dinosharly.parquet",
        "split": "0",
        "set_type": "test",
        "images_folder": "/home/bgamboa/side_projects/HIPT-CH-HER2-SCORING/src/data/image",
    }
)

# %%
import pandas as pd

pd.read_parquet(
    "/home/bgamboa/side_projects/HIPT-CH-HER2-SCORING/src/data/partitions_dinosharly.parquet"
)
# Out:
#                         ImageId ImageClass     partition  new_codigo
# 0        177-UCH-2-IDA-2-30.jpg         3+          test           3
# 1         177-UCH-5-IDA-1-5.jpg         1+          test           1
# 2         177-UCH-1-IDA-1-3.jpg         3+          test           3
# 3        177-UCH-4-IDA-2-15.jpg         1+          test           1
# 4        142-UCH-6-IDA-1-26.jpg         3+          test           3
# ...                         ...        ...           ...         ...
# 4810     177-UCH-4-IDA-1-24.jpg         2+  validation_4           2
# 4811   162-CPDAI-9-IDA-3-66.jpg         2+  validation_4           2
# 4812     177-UCH-2-IDA-2-45.jpg         3+  validation_4           3
# 4813  162-CPDAI-12-IDA-3-14.jpg         1+  validation_4           1
# 4814      142-UCH-2-IDA-1-2.jpg         2+  validation_4           2
#
# [4815 rows x 4 columns]

# %%
data, _ = dataset_debug.__getitem__(100)
